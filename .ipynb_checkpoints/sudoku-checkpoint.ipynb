# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model
from libs import sudukoSolver
from utils import helpers
import signal

# %%
width = 960
height = 720
# Initialisation de la taille des images
heightImg = 450
widthImg = 450

# Durée maximale avant de considérer la grille comme non résolue
timeToResolve = 5
# Dictionnaire pour stocker les grilles résolues
seen = dict()
seenAlready=''
# Indicateur pour le temps écoulé
flag = False
# Chargement du modèle Keras pour la prédiction des chiffres
model = load_model('./model/model_trained.keras')

# %%
imagePath='images/1.png'
img = cv2.imread(imagePath)
#img = cv2.resize(img, (width, height))
img_result = img.copy()

# %%
imgThreshold = helpers.preProcess(img)

# %%
helpers.showImage(imgThreshold)

# %%
contours, hierarchy = helpers.getContours(imgThreshold)
biggest, maxArea, countour = helpers.findBiggestContour(contours)
biggest = helpers.reorderPointsForWarp(biggest)

# %%
imageWithPoint = helpers.drawContours(img, biggest, (255, 0, 255), 25)
imageWithContourAndPoint = helpers.drawContours(imageWithPoint, [countour])
imageAllContours=helpers.drawContours(img, contours)

# %%
helpers.showMultipleImages([imageAllContours,imageWithContourAndPoint])

# %%
# Transformation de perspective pour obtenir une image de grille de Sudoku
pts1 = np.float32(biggest)
pts2 = np.float32([[0, 0],[widthImg, 0], [0, heightImg],[widthImg, heightImg]])
matrix = cv2.getPerspectiveTransform(pts1, pts2)
imgWarpColored = cv2.warpPerspective(img, matrix, (widthImg, heightImg))

# Prétraitement de l'image de la grille
imgWarpProcessed = helpers.preProcess(imgWarpColored)
helpers.showMultipleImages([imgWarpColored,imgWarpProcessed])

# %%
vertical_lines, horizontal_lines = helpers.get_grid_lines(imgWarpProcessed)
maskGrid = helpers.create_grid_mask(vertical_lines, horizontal_lines)
maskGrid2 = helpers.create_grid_mask2(vertical_lines, horizontal_lines)
helpers.showMultipleImages([vertical_lines,horizontal_lines,maskGrid2,maskGrid],4)

# %%
#s'ils sont pareils je le garde
numbersImages = cv2.bitwise_and(imgWarpProcessed, maskGrid)
helpers.showMultipleImages([imgWarpProcessed,maskGrid,numbersImages],3)

# %%
squares = helpers.split_into_squares(numbersImages)
squares_processed = helpers.clean_squares(squares)

# %%
helpers.showMultipleImages(squares[:5],5)
helpers.showMultipleImages(squares_processed[:5],5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 helpers.showMultipleImages(squares[:5],5)
# ----> 2 helpers.showImage(squares_processed[:5],5)
#
# File ~/Documents/projets/perso/deepLearning/resolve_sudoku/utils/helpers.py:78, in showImage(img, name)
#      77 def showImage(img, name='my-image'):
# ---> 78     plt.imshow(img,cmap='gray')
#      79     plt.title(name)
#      80     plt.axis('off')
#
# File ~/anaconda3/envs/DeepL/lib/python3.11/site-packages/matplotlib/pyplot.py:3343, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3322 @_copy_docstring_and_deprecators(Axes.imshow)
#    3323 def imshow(
#    3324     X: ArrayLike | PIL.Image.Image,
#    (...)
#    3341     **kwargs,
#    3342 ) -> AxesImage:
# -> 3343     __ret = gca().imshow(
#    3344         X,
#    3345         cmap=cmap,
#    3346         norm=norm,
#    3347         aspect=aspect,
#    3348         interpolation=interpolation,
#    3349         alpha=alpha,
#    3350         vmin=vmin,
#    3351         vmax=vmax,
#    3352         origin=origin,
#    3353         extent=extent,
#    3354         interpolation_stage=interpolation_stage,
#    3355         filternorm=filternorm,
#    3356         filterrad=filterrad,
#    3357         resample=resample,
#    3358         url=url,
#    3359         **({"data": data} if data is not None else {}),
#    3360         **kwargs,
#    3361     )
#    3362     sci(__ret)
#    3363     return __ret
#
# File ~/anaconda3/envs/DeepL/lib/python3.11/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File ~/anaconda3/envs/DeepL/lib/python3.11/site-packages/matplotlib/axes/_axes.py:5756, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5753 if aspect is not None:
#    5754     self.set_aspect(aspect)
# -> 5756 im.set_data(X)
#    5757 im.set_alpha(alpha)
#    5758 if im.get_clip_path() is None:
#    5759     # image does not already have clipping set, clip to axes patch
#
# File ~/anaconda3/envs/DeepL/lib/python3.11/site-packages/matplotlib/image.py:723, in _ImageBase.set_data(self, A)
#     721 if isinstance(A, PIL.Image.Image):
#     722     A = pil_to_array(A)  # Needed e.g. to apply png palette.
# --> 723 self._A = self._normalize_image_array(A)
#     724 self._imcache = None
#     725 self.stale = True
#
# File ~/anaconda3/envs/DeepL/lib/python3.11/site-packages/matplotlib/image.py:686, in _ImageBase._normalize_image_array(A)
#     680 @staticmethod
#     681 def _normalize_image_array(A):
#     682     """
#     683     Check validity of image-like input *A* and normalize it to a format suitable for
#     684     Image subclasses.
#     685     """
# --> 686     A = cbook.safe_masked_invalid(A, copy=True)
#     687     if A.dtype != np.uint8 and not np.can_cast(A.dtype, float, "same_kind"):
#     688         raise TypeError(f"Image data of dtype {A.dtype} cannot be "
#     689                         f"converted to float")
#
# File ~/anaconda3/envs/DeepL/lib/python3.11/site-packages/matplotlib/cbook.py:733, in safe_masked_invalid(x, copy)
#     732 def safe_masked_invalid(x, copy=False):
# --> 733     x = np.array(x, subok=True, copy=copy)
#     734     if not x.dtype.isnative:
#     735         # If we have already made a copy, do the byteswap in place, else make a
#     736         # copy with the byte order swapped.
#     737         # Swap to native order.
#     738         x = x.byteswap(inplace=copy).view(x.dtype.newbyteorder('N'))
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (5,) + inhomogeneous part.
